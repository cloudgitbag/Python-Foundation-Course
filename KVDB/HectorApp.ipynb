# %%
from vehicles.hector import Car,Hector

if __name__ =="__main__":
    print(__name__)
    car1 = Car()
    car1.start()
    car1.show_state()

    hector1 = Hector()
    hector1.start()
    hector1.show_state()
