# %% [markdown]
# # Practice Exercise - 06

# %% [markdown]
# ### Question 1:
#
# Write a Python function to check whether the number given below is present in between 5 to 10 (both included) or not.
#
# num = 7
#
# #### Expected Output:
#
# 7 is present between 5-10.

# %%
def IsExist(num):
    return True if num in range(5,11) else False
    
digit=7
if IsExist(digit):
    print(f"{digit} is present between 5-10.")
else:
    print(f"{digit} is not present between 5-10.")

# %% [markdown]
# ### Question 2:
#
# Write a Python function that accepts two arguments and calculates the addition and subtraction of it. Also, print both the arithmetic results in a single return call.
#
# #### Expected Output:
#
# (Addition, Substraction) :  (50, 30)

# %%
def AddSubtract(num1,num2):
    return print(f"(Addition, Subtraction):({num1+num2},{num1-num2})")

AddSubtract(30,20)
# add,sub=AddSubtract(30,20)
# print(add,sub)

# %% [markdown]
# ### Question 3:
#
# Create a function in Python that displays the name and results of a candidate. The function should accept the candidate's name and his/her results as "Pass/Fail." If the result is missing in the function call, show it as "Pass."
#
# #### Expected Output:
#
# Sam is Pass.
# <br>Judy is Fail.

# %%
def CandidateCheck(name, result=None):
    print(f"{name} is {'Pass' if result==None else result}")

CandidateCheck("Sam","Pass")
CandidateCheck("Judy","Fail")
CandidateCheck("Carl")

###############################
def exam_results(name, results = "Pass"):
    print(f'{name} is {results}.')

# %% [markdown]
# ### Question 4:
#
# We have a list of numbers given below. Write a Python function to print all the odd-indexed items from the list.
#
# n = [2, 3, 5, 6, 8, 9]
#
# #### Expected Output:
#
# (3, 6, 9)

# %%
def OddIndex(*numlist):
    print(numlist[1::2])

n = [2, 3, 5, 6, 8, 9]
OddIndex(*n)

# %% [markdown]
# ### Question 5:
#
# We have the names of six countries given below. Write a Python function to print all the countries that start with the letter 'A.'
#
# 'Austraiia', 'India', 'Austria', 'America', 'Russia', 'Iran'
#
# #### Expected Output:
#
# ['Austraiia', 'Austria', 'America']

# %%
def ACountries(*country):
    a = [i for i in country if i.startswith("A")]
    print(a)

ACountries('Austraiia', 'India', 'Austria', 'America', 'Russia', 'Iran')

# %% [markdown]
# ### Question 6:
#
# A list of tuples is given below, containing the candidate's name and their heights(in cm). Sort this list using Lambda functions according to the heights of the candidates.
#
# candidate_details = [('Harry', 168), ('Jhonny', 160), ('Brad', 178), ('Chris', 172)]
#
# #### Expected Output:
#
# [('Jhonny', 160), ('Harry', 168), ('Chris', 172), ('Brad', 178)]

# %%
def sortHeight(*candidates):
    print(sorted(candidates, key=lambda x: x[1]))


candidate_details = [('Harry', 168), ('Jhonny', 160), ('Brad', 178), ('Chris', 172)]
sortHeight(*candidate_details)

#########################
candidate_details.sort(key = lambda x: x[1])

# %% [markdown]
# ### Question 7:
#
# Write a Python function to find 'Mall' from the dictionary 'map_details' given below.
#
# map_details = {101:'Park', 102:'Zoo', 103:'Mall'}
#
# #### Expected Output:
#
# 103

# %%
def mapLocation(val, map_details):
    location= next(k for k,v in map_details.items() if v==val)
    print(location)

map_details = {101:'Park', 102:'Zoo', 103:'Mall'}
mapLocation('Mall',map_details)

######################################
def find(**dict_1):
    print(dict_1['Mall'])
    
find(**map_details)

# %% [markdown]
# ### Question 8:
#
# Write a Python program to add the three lists given below using Python map and Lambda function.
#
# list_1 = [1, 5, 8]
# <br>list_2 = [3, 2, 5]
# <br>list_3 = [2, 3, 6]
#
# #### Expected Output:
#
# Resultant List: [6, 10, 19]

# %%
def addList(*list):
    print(list)
    return [sum(map(lambda x:x,s)) for s in list]

def addListperIndex(*list):
    print(list)
    result = [sum(col) for col in zip(*list)]
    print(result)

def addListperCol(*list):
    result = [sum(map(lambda x:x,s)) for s in zip(*list)]
    print(f"Resultant List: {result}")

list_1 = [1, 5, 8]
list_2 = [3, 2, 5]
list_3 = [2, 3, 6]

#addList(list_1,list_2,list_3)
#addListperIndex(list_1,list_2,list_3)
addListperCol(list_1,list_2,list_3)
#################################################
result = map(lambda x, y, z: x + y + z, list_1, list_2, list_3)

# %% [markdown]
# ### Question 9:
#
# We have the marks of a student in each subject given below. Write a Python function that takes two parameters 'name' and 'subjects_marks.' Finally, print the student's name and all the subjects in which his/her marks are above 60. If the 'name' is not provided, print 'None.'
#
# Mathematics = 80, Physics = 58, Chemistry = 62, English = 72, Biology = 50
#
# #### Expected Output:
#
# Name:  Brandon - Subjects:  {'Chemistry', 'English', 'Mathematics'}

# %%
def FinalGrades(name=None,**subjects_marks):
    passingGrades1 = {k for k,v in subjects_marks.items() if v>=60}
    #passingGrades2 = {lambda k,v: k if v>=60 else None for k,v in subjects_marks.items()}
    print(f"Name:{name}-Subjects:{passingGrades1}")
    #print(f"Name:{name}-Subjects:{passingGrades2}")

FinalGrades("John",Maths=50,Science=60,English=70)
FinalGrades("Brandon",Mathematics = 80, Physics = 58, Chemistry = 62, English = 72, Biology = 50)

#######################################
def marks_check(name = None, **subject_marks):
    res = {subject_name for (subject_name, marks) in subject_marks.items() if marks > 60}
    print("Name: ", name,"- Subjects: ", res)

# %% [markdown]
# ### Question 10:
#
# Using Lambda function, extract and print the year from the datetime object given below.
#
# given_date = datetime(2008, 6, 12, 10, 30, 0)
#
# #### Expected Output:
#
# 2008

# %%
import datetime as dt

given_date = dt.datetime(2008, 6, 12, 10, 30, 0)
x =lambda x: x.strftime("%Y")
print(x(given_date))

#################################
year = lambda x : x.year
print(year(given_date))
